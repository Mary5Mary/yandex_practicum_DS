# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Прверка-эффективность-обогащения" data-toc-modified-id="Прверка-эффективность-обогащения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Прверка эффективность обогащения</a></span></li><li><span><a href="#Анализируйте-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализируйте-признаков,-недоступных-в-тестовой-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Анализируйте признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Проведем-предобработку-данных." data-toc-modified-id="Проведем-предобработку-данных.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проведем предобработку данных.</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрим,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки." data-toc-modified-id="Посмотрим,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.</a></span></li><li><span><a href="#Сравним-распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Сравним-распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравним распределение размеров гранул сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишем-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Напишем-функцию-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Напишем функцию для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#Проверим-признаки-на-корреляцию" data-toc-modified-id="Проверим-признаки-на-корреляцию-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Проверим признаки на корреляцию</a></span></li><li><span><a href="#Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией." data-toc-modified-id="Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучите разные модели и оцените их качество кросс-валидацией.</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# Данные находятся в трёх файлах:
# 1. gold_recovery_train_new.csv — обучающая выборка;
# 2. gold_recovery_test_new.csv — тестовая выборка;
# 3. gold_recovery_full_new.csv — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак date).
# Соседние по времени параметры часто похожи.
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
# В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Загрузка данных

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error, make_scorer
import matplotlib.pyplot as plt
from math import sqrt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor

# %%
pd.options.mode.chained_assignment = None

# %%
recovery_train = pd.read_csv('/datasets/gold_recovery_train_new.csv', index_col='date')
recovery_test = pd.read_csv('/datasets/gold_recovery_test_new.csv', index_col='date')
recovery_full = pd.read_csv('/datasets/gold_recovery_full_new.csv', index_col='date')

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
#     <p>ОК, данные на базе)</p>
# </div>

# %%
recovery_train.info()
recovery_test.info()
recovery_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         14148 non-null  float64
#  1   final.output.concentrate_pb                         14148 non-null  float64
#  2   final.output.concentrate_sol                        13938 non-null  float64
#  3   final.output.concentrate_au                         14149 non-null  float64
#  4   final.output.recovery                               14149 non-null  float64
#  5   final.output.tail_ag                                14149 non-null  float64
#  6   final.output.tail_pb                                14049 non-null  float64
#  7   final.output.tail_sol                               14144 non-null  float64
# ...

# %% [markdown]
# ***Описание данных***
#
# Технологический процесс
# * Rougher feed — исходное сырье
# * Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant,
# * Xanthate — ксантогенат (промотер, или активатор флотации);
# * Sulphate — сульфат (на данном производстве сульфид натрия);
# * Depressant — депрессант (силикат натрия).
# * Rougher process (англ. «грубый процесс») — флотация
# * Rougher tails — отвальные хвосты
# * Float banks — флотационная установка
# * Cleaner process — очистка
# * Rougher Au — черновой концентрат золота
# * Final Au — финальный концентрат золота
#
# Параметры этапов
# * air amount — объём воздуха
# * fluid levels — уровень жидкости
# * feed size — размер гранул сырья
# * feed rate — скорость подачи
# * Наименование признаков
# * Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
# Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
# * rougher — флотация
# * primary_cleaner — первичная очистка
# * secondary_cleaner — вторичная очистка
# * final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
# * input — параметры сырья
# * output — параметры продукта
# * state — параметры, характеризующие текущее состояние этапа
# * calculation — расчётные характеристики

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
# <font color='green'><br>
# ок, первичный аналитический осмотр на месте. Кажется обыденным пунктом, но много идей может рождать. ПОэтому и важно его проводить.

# %% [markdown]
# ### Прверка эффективность обогащения

# %% [markdown]
# Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# C — доля золота в концентрате после флотации/очистки;
# F — доля золота в сырье/концентрате до флотации/очистки;
# T — доля золота в отвальных хвостах после флотации/очистки.

# %%
# Сброс ограничений на количество выводимых рядов
pd.set_option('display.max_rows', None)
 
# Сброс ограничений на число столбцов
pd.set_option('display.max_columns', None)
 
# Сброс ограничений на количество символов в записи
pd.set_option('display.max_colwidth', None)

# %%
recovery_train['rougher.output.recovery_my'] = 100*(recovery_train['rougher.output.concentrate_au']*(recovery_train['rougher.input.feed_au'] - recovery_train['rougher.output.tail_au']))/(recovery_train['rougher.input.feed_au'] * (recovery_train['rougher.output.concentrate_au'] - recovery_train['rougher.output.tail_au']
))

# %% [markdown]
# Найдем MAE между расчётами и значением признака.

# %%
print(mean_absolute_error(recovery_train['rougher.output.recovery_my'], recovery_train['rougher.output.recovery']))
# Out:
# 1.1131451184435918e-14

# %% [markdown]
# MAE между расчётами и значением признака стремится к 0

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
# <font color='green'>
# есть контакт)

# %% [markdown]
# ### Анализируйте признаков, недоступных в тестовой выборке

# %% [markdown]
# Целевые  признаки
#
# `'rougher.output.recovery'`
# `'final.output.recovery'`

# %%
col_not_test = []
for columns in recovery_full.columns:
    if columns not in recovery_test.columns:
        col_not_test.append(columns)

col_not_test = pd.Series(col_not_test)
col_not_test  = col_not_test.loc[(col_not_test  != 'rougher.output.recovery')&(col_not_test  != 'final.output.recovery')]
display(col_not_test)
# Out:
# 0                            final.output.concentrate_ag
# 1                            final.output.concentrate_pb
# 2                           final.output.concentrate_sol
# 3                            final.output.concentrate_au
# 5                                   final.output.tail_ag
# 6                                   final.output.tail_pb
# 7                                  final.output.tail_sol
# 8                                   final.output.tail_au
# 9                  primary_cleaner.output.concentrate_ag
# 10                 primary_cleaner.output.concentrate_pb
# 11                primary_cleaner.output.concentrate_sol
# 12                 primary_cleaner.output.concentrate_au
# 13                        primary_cleaner.output.tail_ag
# 14                        primary_cleaner.output.tail_pb
# 15                       primary_cleaner.output.tail_sol
# 16                        primary_cleaner.output.tail_au
# ...

# %%
recovery_train = recovery_train.drop_duplicates()
recovery_full = recovery_full.drop_duplicates()
recovery_test = recovery_test.drop_duplicates()
print(recovery_train.shape,
recovery_full.shape,
recovery_test.shape)
# Out:
# (14149, 87) (19439, 86) (5290, 52)

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
# согласен.<br>
# В тестовой выборке недоступны некоторые расчетные (calculation) и выходные (output) характеристики процесса, т.к. их невозможно получить/измерить во время выполнения технологического процесса.

# %% [markdown]
# в test нет 34 колонок из train
#
# сопоставим  2 колонки из fullс целевыми признаками для test
#
# удалим из train колонки, которые отстутствуют  в test

# %%
recovery_train1 = recovery_train.drop(columns = col_not_test)
print(recovery_train1.shape)
# Out:
# (14149, 55)

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
# согласен.<br>
# да, это важно было - привести в соответствие трайн и тест.

# %%
target_columns = ['final.output.recovery','rougher.output.recovery']

# %%
recovery_test_target = recovery_test.join(recovery_full.loc[recovery_test.index][['final.output.recovery','rougher.output.recovery']])
recovery_test_target.tail()
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2017-12-31 19:59:59                     173.957757
# 2017-12-31 20:59:59                     172.910270
# 2017-12-31 21:59:59                     171.135718
# 2017-12-31 22:59:59                     179.697158
# 2017-12-31 23:59:59                     181.556856
#
#                      primary_cleaner.input.depressant  \
# date
# 2017-12-31 19:59:59                         15.963399
# 2017-12-31 20:59:59                         16.002605
# 2017-12-31 21:59:59                         15.993669
# 2017-12-31 22:59:59                         15.438979
# 2017-12-31 23:59:59                         14.995850
#
#                      primary_cleaner.input.feed_size  \
# date
# 2017-12-31 19:59:59                             8.07
# 2017-12-31 20:59:59                             8.07
# 2017-12-31 21:59:59                             8.07
# 2017-12-31 22:59:59                             8.07
# ...

# %% [markdown]
# ### Проведем предобработку данных.
#
# проверим колличество пропущенных значений

# %%
for col in recovery_train1.columns:
    pct_missing = np.mean(recovery_train1[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# final.output.recovery - 0%
# primary_cleaner.input.sulfate - 0%
# primary_cleaner.input.depressant - 0%
# primary_cleaner.input.feed_size - 0%
# primary_cleaner.input.xanthate - 1%
# primary_cleaner.state.floatbank8_a_air - 0%
# primary_cleaner.state.floatbank8_a_level - 0%
# primary_cleaner.state.floatbank8_b_air - 0%
# primary_cleaner.state.floatbank8_b_level - 0%
# primary_cleaner.state.floatbank8_c_air - 0%
# primary_cleaner.state.floatbank8_c_level - 0%
# primary_cleaner.state.floatbank8_d_air - 0%
# primary_cleaner.state.floatbank8_d_level - 0%
# rougher.input.feed_ag - 0%
# rougher.input.feed_pb - 1%
# rougher.input.feed_rate - 0%
# rougher.input.feed_size - 1%
# rougher.input.feed_sol - 1%
# rougher.input.feed_au - 0%
# rougher.input.floatbank10_sulfate - 0%
# rougher.input.floatbank10_xanthate - 0%
# rougher.input.floatbank11_sulfate - 0%
# rougher.input.floatbank11_xanthate - 3%
# rougher.output.recovery - 0%
# rougher.state.floatbank10_a_air - 0%
# ...

# %%
for col in recovery_test_target.columns:
    pct_missing = np.mean(recovery_test_target[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# primary_cleaner.input.sulfate - 0%
# primary_cleaner.input.depressant - 0%
# primary_cleaner.input.feed_size - 0%
# primary_cleaner.input.xanthate - 0%
# primary_cleaner.state.floatbank8_a_air - 0%
# primary_cleaner.state.floatbank8_a_level - 0%
# primary_cleaner.state.floatbank8_b_air - 0%
# primary_cleaner.state.floatbank8_b_level - 0%
# primary_cleaner.state.floatbank8_c_air - 0%
# primary_cleaner.state.floatbank8_c_level - 0%
# primary_cleaner.state.floatbank8_d_air - 0%
# primary_cleaner.state.floatbank8_d_level - 0%
# rougher.input.feed_ag - 0%
# rougher.input.feed_pb - 0%
# rougher.input.feed_rate - 0%
# rougher.input.feed_size - 0%
# rougher.input.feed_sol - 0%
# rougher.input.feed_au - 0%
# rougher.input.floatbank10_sulfate - 0%
# rougher.input.floatbank10_xanthate - 0%
# rougher.input.floatbank11_sulfate - 0%
# rougher.input.floatbank11_xanthate - 0%
# rougher.state.floatbank10_a_air - 0%
# rougher.state.floatbank10_a_level - 0%
# rougher.state.floatbank10_b_air - 0%
# ...

# %%
colum = recovery_train1.columns
fig = plt.figure(figsize=(16,6))
colours = ['#000099', '#ffff00'] 
sns.heatmap(recovery_train1[colum].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:ylabel='date'>

# %%
(100*recovery_train1.isna().sum()/recovery_train1.shape[0]).sort_values().\
plot(kind = 'bar',figsize = (12,12),title = 'Количество пропусков в столбцах на тренировочной выборке, в %')
plt.xlabel('признаки')
plt.ylabel('% пропусков от выборки')
plt.show()

# %% [markdown]
# Заметим, что пропусков мало, максимум  3%, поэтому удалим их из тестовой и тренировочной выборок

# %%
recovery_train1 = recovery_train1.dropna()

# %%
recovery_test_target = recovery_test_target.dropna()

# %%
print(recovery_train.shape,  recovery_train1.shape, 100*(1-recovery_train1.shape[0]/recovery_train.shape[0]))
# Out:
# (14149, 87) (12679, 55) 10.389426814615877

# %%
print(recovery_test.shape,recovery_test_target.shape, 100*(1-recovery_test_target.shape[0]/recovery_test.shape[0]))
# Out:
# (5290, 52) (5229, 54) 1.153119092627597

# %% [markdown]
# На тренеровочной выборке было удалено 10%, на тестовой 1%.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %%
def plot_distplot(df,col1,col2,col3,title): 
    fig = plt.figure(figsize=(10,6))
    sns.histplot(df[col1], color = 'red',kde=True, linewidth=0)
    sns.histplot(df[col2], color = 'green', kde=True, linewidth=0)
    sns.histplot(df[col3], color = 'pink', kde=True, linewidth=0)

    fig.legend([col1,col2,col3])
    plt.xlabel(title)
    plt.ylabel('значения параметра')
    plt.grid()
    plt.show()

# %%
plot_distplot(df = recovery_full,
              col1 = 'rougher.output.concentrate_au',
              col2 = 'primary_cleaner.output.concentrate_au',
              col3 = 'final.output.concentrate_au',
              title = 'Концентрация золота (Au) на основных этапах')

# %%
plot_distplot(df = recovery_full,
              col1 = 'rougher.output.concentrate_ag',
              col2 = 'primary_cleaner.output.concentrate_ag',
              col3 = 'final.output.concentrate_ag',
             
              title = 'Концентрация серебра (Ag) на основных этапах',
)

# %%
plot_distplot(df = recovery_full,
              col1 = 'rougher.output.concentrate_pb',
              col2 = 'primary_cleaner.output.concentrate_pb',
              col3 = 'final.output.concentrate_pb',
              title = 'Концентрация свинца (Pb) на основных этапах')

# %%
plot_distplot(df = recovery_full,
              col1 = 'rougher.output.tail_ag',
              col2 = 'primary_cleaner.output.tail_ag',
              col3 = 'final.output.tail_ag',
              title = 'Концентрация серебра (Ag) в отвальных хвостах')

# %%
plot_distplot(df = recovery_full,
              col1 = 'rougher.output.tail_au',
              col2 = 'primary_cleaner.output.tail_au',
              col3 = 'final.output.tail_au',
              title = 'Концентрация золота (Au) в отвальных хвостах')

# %% [markdown]
# Au:
# концентрация золота в породе с каждым этап возрастает
#
# в отвальных хвостах концентрации почти не меняется.
#
# Ag:
#
# концентрация серебра в породе с каждым этап падает, а в хвостах наоборот возрастает;
#
# Pb:
#
# концентрация свинца увеличивается с каждым этапом, аналогично в отвальных хвостах.

# %% [markdown]
# ### Сравним распределение размеров гранул сырья на обучающей и тестовой выборках.

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(recovery_test['primary_cleaner.input.feed_size'], color = 'red',kde=True, linewidth=0, legend = 'recovery_test')
sns.histplot(recovery_train['primary_cleaner.input.feed_size'], color = 'green', kde=True, linewidth=0, legend = 'recovery_train')
plt.ylabel('primary_cleaner.input.feed_size')
fig.legend(['recovery_test', 'recovery_train'])
plt.grid()
plt.show()
print('test', recovery_test['primary_cleaner.input.feed_size'].mean())
print('train', recovery_train['primary_cleaner.input.feed_size'].mean())
print('Разница между средними: ', recovery_test['primary_cleaner.input.feed_size'].mean() - recovery_train['primary_cleaner.input.feed_size'].mean())
# Out:
# test 7.266339191270906
# train 7.322309906901314
# Разница между средними:  -0.055970715630407675

# %%
#primary_cleaner.input.feed_size
#rougher.input.feed_size 
fig = plt.figure(figsize=(10,6))
sns.histplot(recovery_test['rougher.input.feed_size'], color = 'red',kde=True, linewidth=0, legend = 'test')
sns.histplot(recovery_train['rougher.input.feed_size'], color = 'green', kde=True, linewidth=0, legend = 'train')
plt.ylabel('rougher.input.feed_size')
fig.legend(['test', 'train'])
plt.grid()
plt.show()
print('test', recovery_test['rougher.input.feed_size'].mean())
print('train', recovery_train['rougher.input.feed_size'].mean())
print('Разница между средними: ', recovery_test['rougher.input.feed_size'].mean() - recovery_train['rougher.input.feed_size'].mean())
# Out:
# test 55.951097447596965
# train 60.11051805066844
# Разница между средними:  -4.159420603071474

# %% [markdown]
# Разница размеров гранул маленькая

# %% [markdown]
# ### Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
final_output_concentrate = ['final.output.concentrate_ag',
'final.output.concentrate_pb',
'final.output.concentrate_au',
'final.output.concentrate_sol']

final_output_tail = ['final.output.tail_ag',
'final.output.tail_pb',
'final.output.tail_au',
'final.output.tail_sol']

primary_cleaner_output_concentrate = ['primary_cleaner.output.concentrate_ag',
'primary_cleaner.output.concentrate_pb',
'primary_cleaner.output.concentrate_au',
'primary_cleaner.output.concentrate_sol']

primary_cleaner_output_tail = ['primary_cleaner.output.tail_ag',
'primary_cleaner.output.tail_pb',
'primary_cleaner.output.tail_au',
'primary_cleaner.output.tail_sol']

rougher_input_feed = ['rougher.input.feed_ag',
'rougher.input.feed_pb',
'rougher.input.feed_au',
'rougher.input.feed_sol']

rougher_output_concentrate = ['rougher.output.concentrate_ag',
'rougher.output.concentrate_pb',
'rougher.output.concentrate_au',
'rougher.output.concentrate_sol']

rougher_output_tail = ['rougher.output.tail_ag',
'rougher.output.tail_pb',
'rougher.output.tail_au',
'rougher.output.tail_sol']

secondary_cleaner_output_tail = ['secondary_cleaner.output.tail_ag',
'secondary_cleaner.output.tail_pb',
'secondary_cleaner.output.tail_au',
'secondary_cleaner.output.tail_sol']

colum_sub = set(['final.output.concentrate_ag',
'final.output.concentrate_pb',
'final.output.concentrate_au',
'final.output.concentrate_sol','final.output.tail_ag',
'final.output.tail_pb',
'final.output.tail_au',
'final.output.tail_sol','primary_cleaner.output.concentrate_ag',
'primary_cleaner.output.concentrate_pb',
'primary_cleaner.output.concentrate_au',
'primary_cleaner.output.concentrate_sol','primary_cleaner.output.tail_ag',
'primary_cleaner.output.tail_pb',
'primary_cleaner.output.tail_au',
'primary_cleaner.output.tail_sol','rougher.input.feed_ag',
'rougher.input.feed_pb',
'rougher.input.feed_au',
'rougher.input.feed_sol','rougher.output.concentrate_ag',
'rougher.output.concentrate_pb',
'rougher.output.concentrate_au',
'rougher.output.concentrate_sol','rougher.output.tail_ag',
'rougher.output.tail_pb',
'rougher.output.tail_au',
'rougher.output.tail_sol','secondary_cleaner.output.tail_ag',
'secondary_cleaner.output.tail_pb',
'secondary_cleaner.output.tail_au',
'secondary_cleaner.output.tail_sol']) - set(col_not_test)
colum_sub
# Out:
# {'rougher.input.feed_ag',
#  'rougher.input.feed_au',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_sol'}

# %% [markdown]
# В измененном трене и тесте присутствуют только значения веществ в исходном сырье.

# %%
df_colum_sub = [final_output_concentrate, 
final_output_tail, 
primary_cleaner_output_concentrate, 
primary_cleaner_output_tail, 
rougher_input_feed, 
rougher_output_concentrate, 
rougher_output_tail, 
secondary_cleaner_output_tail]
index = ['final_output_concentrate', 'final_output_tail',  
    'primary_cleaner_output_concentrate', 
    'primary_cleaner_output_tail', 
    'rougher_input_feed', 
    'rougher_output_concentrate', 
    'rougher_output_tail', 
    'secondary_cleaner_output_tail']

# %%
def sum_substance(df, colums):
    df_return = df[colums[1]]+df[colums[2]]+df[colums[3]]+df[colums[0]]
    return df_return

# %%
sum_substance_df = []
for i in df_colum_sub:
    sum_substance_df.append(sum_substance(recovery_train, i))

# %%
sum_substance_df=pd.DataFrame(sum_substance_df, index = index).transpose()

# %%
fig = plt.figure(figsize=(15,10))
sns.histplot(sum_substance_df, kde=True, linewidth=0)
plt.grid()
plt.show()

# %%
fig, scatter = plt.subplots(figsize = (20,7))
scatter = sns.boxplot(data=sum_substance_df)

# %% [markdown]
# Заметим, что присутствуют выбросы у нуля. Отбросим выбросы с низу

# %%
sum_substance_df.describe().T
# Out:
#                                       count       mean        std        min  \
# final_output_concentrate            13937.0  68.485831   7.015500   0.000000
# final_output_tail                   14044.0  25.657989   4.591078   0.000000
# primary_cleaner_output_concentrate  13863.0  60.363526  10.397056   0.000000
# primary_cleaner_output_tail         14088.0  31.097779   5.484449   0.000000
# rougher_input_feed                  13976.0  56.341625   6.980747   0.040000
# rougher_output_concentrate          14127.0  67.196296  12.697690   0.000000
# rougher_output_tail                 14148.0  25.857666   3.429077  16.006292
# secondary_cleaner_output_tail       12533.0  30.525908   9.017616   0.000000
#
#                                           25%        50%        75%        max
# final_output_concentrate            67.651658  69.180810  71.013556  80.210644
# final_output_tail                   23.247141  25.458987  28.100798  43.270605
# ...

# %%
recovery_train2=recovery_train1
for i in colum_sub:
    q75 = recovery_train2[i].quantile(0.75)
    q25 = recovery_train2[i].quantile(0.25)
    intr_qr = q75-q25
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    recovery_train2[i].loc[recovery_train2[i] < min] = np.nan

# %%
colum = recovery_train2.columns
fig = plt.figure(figsize=(10,6))
colours = ['#000099', '#ffff00'] 
sns.heatmap(recovery_train2[colum].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:ylabel='date'>

# %%
for col in recovery_train2.columns:
    pct_missing = np.mean(recovery_train2[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# final.output.recovery - 0%
# primary_cleaner.input.sulfate - 0%
# primary_cleaner.input.depressant - 0%
# primary_cleaner.input.feed_size - 0%
# primary_cleaner.input.xanthate - 0%
# primary_cleaner.state.floatbank8_a_air - 0%
# primary_cleaner.state.floatbank8_a_level - 0%
# primary_cleaner.state.floatbank8_b_air - 0%
# primary_cleaner.state.floatbank8_b_level - 0%
# primary_cleaner.state.floatbank8_c_air - 0%
# primary_cleaner.state.floatbank8_c_level - 0%
# primary_cleaner.state.floatbank8_d_air - 0%
# primary_cleaner.state.floatbank8_d_level - 0%
# rougher.input.feed_ag - 0%
# rougher.input.feed_pb - 0%
# rougher.input.feed_rate - 0%
# rougher.input.feed_size - 0%
# rougher.input.feed_sol - 3%
# rougher.input.feed_au - 0%
# rougher.input.floatbank10_sulfate - 0%
# rougher.input.floatbank10_xanthate - 0%
# rougher.input.floatbank11_sulfate - 0%
# rougher.input.floatbank11_xanthate - 0%
# rougher.output.recovery - 0%
# rougher.state.floatbank10_a_air - 0%
# ...

# %%
(100*recovery_train2.isna().sum()/recovery_train2.shape[0]).sort_values().\
plot(kind = 'bar',figsize = (10,10),title = 'Количество пропусков в столбцах на тренировочной выборке, в %')
plt.xlabel('признаки')
plt.ylabel('% пропусков от выборки')
plt.show()

# %% [markdown]
# Удалим пропуски и проверим выборки

# %%
recovery_train2 = recovery_train2.dropna(subset = colum_sub)
print(recovery_train2.shape, recovery_train.shape)
# Out:
# (12218, 55) (14149, 87)

# %%
recovery_test_target = recovery_test_target.dropna(subset = colum_sub)
print(recovery_test.shape, recovery_test_target.shape)
# Out:
# (5290, 52) (5229, 54)

# %%
recovery_train2_sab = recovery_train2[colum_sub]
fig = plt.figure(figsize=(15,10))
sns.histplot(recovery_train2_sab, kde=True, linewidth=0)
plt.grid()
plt.show()

scatter = sns.boxplot(data=recovery_train2_sab)

# %% [markdown]
# Выбросов снизу нет

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Напишем функцию для вычисления итоговой sMAPE.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def smape_scorer(y_true,y_pred):
    smape = abs((100*abs(y_true-y_pred)/((abs(y_true)+abs(y_pred))/2)).mean())
    return smape

# %%
def final_smape(y_true_r,y_pred_r, y_true_f,y_pred_f):
    f_smape = 0.25*smape_scorer(y_true_r,y_pred_r) + 0.75*smape_scorer(y_true_f,y_pred_f)
    return f_smape

# %% [markdown]
# ### Проверим признаки на корреляцию

# %%
sns.heatmap(recovery_train2.corr())
# Out:
# <AxesSubplot:>

# %%
df_corrr = recovery_train2.corr()
df_cor_big=[]
for i in df_corrr.index:
    for j in df_corrr.columns:
        if i != j:
            if abs(df_corrr[i][j]) >= 0.9 and i not in df_cor_big:
                df_cor_big.append(j)
                
print(df_cor_big)
len(df_cor_big)
# Out:
# ['primary_cleaner.state.floatbank8_b_air', 'primary_cleaner.state.floatbank8_c_air', 'primary_cleaner.state.floatbank8_b_level', 'primary_cleaner.state.floatbank8_c_level', 'rougher.input.floatbank11_sulfate', 'rougher.input.floatbank11_xanthate', 'rougher.output.recovery_my', 'rougher.state.floatbank10_c_air', 'rougher.state.floatbank10_d_air', 'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_level', 'rougher.state.floatbank10_f_air', 'secondary_cleaner.state.floatbank2_b_level']
# 15

# %%
sns.heatmap(recovery_train2[df_cor_big].corr())
# Out:
# <AxesSubplot:>

# %%
df_cor_big_tr = []
for i in df_cor_big:
    if i in recovery_train2.columns:
        df_cor_big_tr.append(i)

# %% [markdown]
# Удалим столбцы с очень высокой корреляцией (0,9)

# %%
recovery_train2 = recovery_train2.drop(columns = df_cor_big_tr)

# %%
#recovery_train2 = recovery_train2.drop(columns = ['date'])

# %%
recovery_test_target = recovery_test_target[recovery_train2.columns]

# %%
print( recovery_train.shape, recovery_train2.shape)
print(recovery_test.shape, recovery_test_target.shape)
# Out:
# (14149, 87) (12218, 40)
# (5290, 52) (5229, 40)

# %%
sns.heatmap(recovery_train2.corr().applymap(lambda x: 0 if x<0.9 else 1))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Обучите разные модели и оцените их качество кросс-валидацией.
#
# Разделим выборки на valid и  target

# %%
x_train = recovery_train2.drop(['final.output.recovery','rougher.output.recovery'], axis=1)
y_train_f = recovery_train2['final.output.recovery']
y_train_r = recovery_train2['rougher.output.recovery']

# %%
x_test = recovery_test_target.drop(['final.output.recovery','rougher.output.recovery'], axis=1)
y_test_f = recovery_test_target['final.output.recovery']
y_test_r = recovery_test_target['rougher.output.recovery']

# %%
y_test_r
# Out:
# date
# 2016-09-01 00:59:59    89.993421
# 2016-09-01 01:59:59    88.089657
# 2016-09-01 02:59:59    88.412756
# 2016-09-01 03:59:59    87.360133
# 2016-09-01 04:59:59    83.236367
# 2016-09-01 05:59:59    79.613867
# 2016-09-01 06:59:59    79.957839
# 2016-09-01 07:59:59    82.183217
# 2016-09-01 08:59:59    83.531184
# 2016-09-01 09:59:59    78.728035
# 2016-09-01 10:59:59    75.811940
# 2016-09-01 11:59:59    76.999993
# 2016-09-01 12:59:59    75.413838
# 2016-09-01 13:59:59    75.497089
# 2016-09-01 14:59:59    79.133894
# 2016-09-01 15:59:59    83.360777
# 2016-09-01 16:59:59    84.680853
# 2016-09-01 17:59:59    83.703965
# 2016-09-01 18:59:59    77.584848
# 2016-09-01 19:59:59    76.004040
# 2016-09-01 20:59:59    68.535623
# 2016-09-01 21:59:59    75.679131
# 2016-09-01 22:59:59    79.271896
# 2016-09-01 23:59:59    77.145809
# 2016-09-02 00:59:59    77.372574
# 2016-09-02 01:59:59    77.245611
# 2016-09-02 02:59:59    73.628052
# 2016-09-02 03:59:59    78.471515
# ...

# %%
def scaler(x_train,x_test):
    ss = StandardScaler()
    ss.fit(x_train)
    train = ss.transform(x_train)
    test = ss.transform(x_test)
    return train,test

# %%
x_train, x_test = scaler(x_train,x_test)

# %%
def metrics(y_true,y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r_2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    smape = smape_scorer(y_true, y_pred)
    return rmse,r_2,mae,smape

# %% [markdown]
# ***Линейная регрессия***

# %%
rougher_model_LR = LinearRegression()
rougher_model_LR.fit(x_train, y_train_r)
predict_LR_r = rougher_model_LR.predict(x_train)
rmse_LR_r, r_2_LR_r, mae_LR_r, smape_LR_r =  metrics(y_train_r, predict_LR_r)
print(rmse_LR_r, r_2_LR_r, mae_LR_r, smape_LR_r)
# Out:
# 11.143458007556484 0.2798428298018727 5.520544771117154 8.659749590866836

# %%
scores = cross_val_score(rougher_model_LR, x_train, y_train_r, cv=5) 
final_score_LR_r = scores.mean()
print('Средняя оценка качества модели:', final_score_LR_r)
scores
# Out:
# Средняя оценка качества модели: -0.3241184426657072
# array([-0.86887622,  0.1396935 ,  0.08727387, -0.08758914, -0.89109423])

# %%
final_model_LR = LinearRegression()
final_model_LR.fit(x_train, y_train_r)
predict_LR_f = rougher_model_LR.predict(x_train)
rmse_LR_f, r_2_LR_f, mae_LR_f, smape_LR_f =  metrics(y_train_f, predict_LR_f)
print(rmse_LR_f, r_2_LR_f, mae_LR_f, smape_LR_f)
# Out:
# 18.416399573106364 -3.2823120075153334 16.563841343621874 22.603229885480577

# %%
scores = cross_val_score(final_model_LR, x_train, y_train_f, cv=5) 
final_score_LR_f = scores.mean()
print('Средняя оценка качества модели:', final_score_LR_f)
# Out:
# Средняя оценка качества модели: -0.26167094587494366

# %%
fsmape_LR = final_smape(y_train_r,predict_LR_r, y_train_f,predict_LR_f)

# %% [markdown]
# ***RandomForestRegressor***

# %% [markdown]
# Подберем гиперпараметры моделей

# %%
RNS = 12345

# %%
#rougher_model_RF = RandomForestRegressor(random_state=RNS)

# %%
#from sklearn.model_selection import RandomizedSearchCV
#n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)]
#max_features = ['log2', 'sqrt']
#max_depth = [int(x) for x in np.linspace(start = 1, stop = 15, num = 15)]
#min_samples_split = [int(x) for x in np.linspace(start = 2, stop = 50, num = 10)]
#min_samples_leaf = [int(x) for x in np.linspace(start = 2, stop = 50, num = 10)]
#bootstrap = [True, False]
#param_dist = {'n_estimators': n_estimators,
              # 'max_features': max_features,
              # 'max_depth': max_depth,
              # 'min_samples_split': min_samples_split,
               #'min_samples_leaf': min_samples_leaf,
               #'bootstrap': bootstrap
#             }
#rs = RandomizedSearchCV(rougher_model_RF, 
#                        param_dist, 
#                        n_iter = 100, 
#                        cv = 5, 
#                        verbose = 1, 
#                        n_jobs=-1, 
#                        random_state=RNS)
#rs.fit(x_train, y_train_r)
#rs.best_params_

# %% [markdown]
# <font color='blue'>
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> очень долго вычесляет
# </div>
#     #{'n_estimators': 100,
# # 'min_samples_split': 18,
# # 'min_samples_leaf': 50,
# # 'max_features': 'log2',
# # 'max_depth': 9,
# # 'bootstrap': True}

# %%
#rs_df = pd.DataFrame(rs.cv_results_).sort_values('rank_test_score').reset_index(drop=True)
#rs_df = rs_df.drop([
#            'mean_fit_time', 
#            'std_fit_time', 
#            'mean_score_time',
#            'std_score_time', 
#            'params', 
#            'split0_test_score', 
#            'split1_test_score', 
#            'split2_test_score', 
#            'std_test_score'],
#            axis=1)
#rs_df.head()

# %%
#fig, axs = plt.subplots(ncols=3, nrows=2)
#sns.set(style="whitegrid", color_codes=True, font_scale = 2)
#fig.set_size_inches(30,25)
#sns.barplot(x='param_n_estimators', y='mean_test_score', data=rs_df, ax=axs[0,0], color='lightgrey')

#axs[0,0].set_title(label = 'n_estimators', weight='bold')
#sns.barplot(x='param_min_samples_split', y='mean_test_score', data=rs_df, ax=axs[0,1], color='coral')

#axs[0,1].set_title(label = 'min_samples_split', size=30, weight='bold')
#sns.barplot(x='param_min_samples_leaf', y='mean_test_score', data=rs_df, ax=axs[0,2], color='lightgreen')

#axs[0,2].set_title(label = 'min_samples_leaf', size=30, weight='bold')
#sns.barplot(x='param_max_features', y='mean_test_score', data=rs_df, ax=axs[1,0], color='wheat')

#axs[1,0].set_title(label = 'max_features', size=30, weight='bold')
#sns.barplot(x='param_max_depth', y='mean_test_score', data=rs_df, ax=axs[1,1], color='lightpink')

#axs[1,1].set_title(label = 'max_depth', size=30, weight='bold')
#sns.barplot(x='param_bootstrap',y='mean_test_score', data=rs_df, ax=axs[1,2], color='skyblue')

#axs[1,2].set_title(label = 'bootstrap', size=30, weight='bold')
#plt.show()

# %% [markdown]
# Заметим, что оптимальные параметры n_estimators = [100, 300 , 400]
# max_features = ['log2']
# max_depth = [9, 12]
# min_samples_split = [18, 23, 34]
# min_samples_leaf = [43, 44, 45, 49, 50]
# bootstrap = [True]

# %%
#n_estimators = [100, 300 , 400, 600]
#max_features = ['log2']
#max_depth = [9,  12]
#min_samples_split = [18, 23, 34]
#min_samples_leaf = [43, 44, 45, 49, 50]
#bootstrap = [True]
#param_grid = {'n_estimators': n_estimators,
               #'max_features': max_features,
#               'max_depth': max_depth,
               #'min_samples_split': min_samples_split,
               #'min_samples_leaf': min_samples_leaf,
               #'bootstrap': bootstrap
#             }
#gs = GridSearchCV(rougher_model_RF, param_grid, cv = 3, verbose = 1, n_jobs=-1)
#gs.fit(x_train, y_train_r)
#rfc_3 = gs.best_estimator_
#gs.best_params_

# %%
rougher_model_RF =  RandomForestRegressor(
    random_state=RNS, 
#    bootstrap=True,
    max_depth = 9,
#    max_features = 'log2',
#    min_samples_leaf=45,
#    min_samples_split=18,
    n_estimators=100
)

rougher_model_RF.fit(x_train, y_train_r)
predict_RF_r = rougher_model_RF.predict(x_train)

rmse_RF_r, r_2_RF_r, mae_RF_r, smape_RF_r =  metrics(y_train_r, predict_RF_r)
print(rmse_RF_r, r_2_LR_r, mae_RF_r, smape_RF_r)
# Out:
# 6.286826643328356 0.2798428298018727 3.1953771153175747 6.73891866298833

# %%
scores = cross_val_score(rougher_model_RF, x_train, y_train_r, cv=5) 
final_score_RF_r = scores.mean()
print('Средняя оценка качества модели:', final_score_RF_r)
# Out:
# Средняя оценка качества модели: -0.43775166103972196

# %%
#final_model_RF = RandomForestRegressor(random_state=RNS)

# %%
#from sklearn.model_selection import RandomizedSearchCV
#n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)]
#max_features = ['log2', 'sqrt']
#max_depth = [int(x) for x in np.linspace(start = 1, stop = 15, num = 15)]
#min_samples_split = [int(x) for x in np.linspace(start = 2, stop = 50, num = 10)]
#min_samples_leaf = [int(x) for x in np.linspace(start = 2, stop = 50, num = 10)]
#bootstrap = [True, False]
#param_dist = {'n_estimators': n_estimators,
#               'max_features': max_features,
#               'max_depth': max_depth,
#               'min_samples_split': min_samples_split,
#               'min_samples_leaf': min_samples_leaf,
#               'bootstrap': bootstrap}
#rs = RandomizedSearchCV(final_model_RF, 
#                        param_dist, 
#                        n_iter = 100, 
#                        cv = 5, 
#                        verbose = 1, 
#                        n_jobs=-1, 
#                        random_state=RNS)
#rs.fit(x_train, y_train_f)
#rs.best_params_

#{'n_estimators': 100,
# 'min_samples_split': 18,
# 'min_samples_leaf': 50,
# 'max_features': 'log2',
# 'max_depth': 9,
# 'bootstrap': True}

# %%
#rs_df = pd.DataFrame(rs.cv_results_).sort_values('rank_test_score').reset_index(drop=True)
#rs_df = rs_df.drop([
#            'mean_fit_time', 
#            'std_fit_time', 
#            'mean_score_time',
#            'std_score_time', 
#            'params', 
#            'split0_test_score', 
#            'split1_test_score', 
#            'split2_test_score', 
#            'std_test_score'],
#            axis=1)
#rs_df.head()

# %%
#fig, axs = plt.subplots(ncols=3, nrows=2)
#sns.set(style="whitegrid", color_codes=True, font_scale = 2)
#fig.set_size_inches(30,25)
#sns.barplot(x='param_n_estimators', y='mean_test_score', data=rs_df, ax=axs[0,0], color='lightgrey')

#axs[0,0].set_title(label = 'n_estimators', weight='bold')
#sns.barplot(x='param_min_samples_split', y='mean_test_score', data=rs_df, ax=axs[0,1], color='coral')

#axs[0,1].set_title(label = 'min_samples_split', size=30, weight='bold')
#sns.barplot(x='param_min_samples_leaf', y='mean_test_score', data=rs_df, ax=axs[0,2], color='lightgreen')

#axs[0,2].set_title(label = 'min_samples_leaf', size=30, weight='bold')
#sns.barplot(x='param_max_features', y='mean_test_score', data=rs_df, ax=axs[1,0], color='wheat')

#axs[1,0].set_title(label = 'max_features', size=30, weight='bold')
#sns.barplot(x='param_max_depth', y='mean_test_score', data=rs_df, ax=axs[1,1], color='lightpink')

#axs[1,1].set_title(label = 'max_depth', size=30, weight='bold')
#sns.barplot(x='param_bootstrap',y='mean_test_score', data=rs_df, ax=axs[1,2], color='skyblue')

#axs[1,2].set_title(label = 'bootstrap', size=30, weight='bold')
#plt.show()

# %%
#n_estimators = [600,900]
#max_features = ['sqrt']
#max_depth = [7,11,15]
#min_samples_split = [12,18]
#min_samples_leaf = [2,7,18]
#bootstrap = [False]
#param_grid = {'n_estimators': n_estimators,
#               'max_features': max_features,
#               'max_depth': max_depth,
#               'min_samples_split': min_samples_split,
#               'min_samples_leaf': min_samples_leaf,
#               'bootstrap': bootstrap
#             }
#gs = GridSearchCV(final_model_RF, param_grid, cv = 5, verbose = 1, n_jobs=-1)
#gs.fit(x_train, y_train_f)
#rfc_3 = gs.best_estimator_
#gs.best_params_

# %%
final_model_RF =  RandomForestRegressor(
    random_state=RNS, 
#    bootstrap=False,
    max_depth = 9,
#    max_features = 'sqrt',
#    min_samples_leaf=2,
#    min_samples_split=2,
    n_estimators=100
)

final_model_RF.fit(x_train, y_train_f)
predict_RF_f = final_model_RF.predict(x_train)

rmse_RF_f, r_2_RF_f, mae_RF_f, smape_RF_f =  metrics(y_train_f, predict_RF_f)

# %%
fsmape_RF = final_smape(y_train_r,predict_RF_r, y_train_f,predict_RF_f)

# %%
scores = cross_val_score(final_model_RF, x_train, y_train_f, cv=5) 
final_score_RF_f = scores.mean()
print('Средняя оценка качества модели:', final_score_RF_f)
# Out:
# Средняя оценка качества модели: -0.09173297985127346

# %%
df_final_metric = pd.DataFrame(
    [[rmse_RF_f, r_2_RF_f, mae_RF_f, smape_RF_f,fsmape_RF, final_score_RF_f], 
    [rmse_RF_r, r_2_RF_r, mae_RF_r, smape_RF_r,fsmape_RF,final_score_RF_r],
    [rmse_LR_f, r_2_LR_f, mae_LR_f, smape_LR_f,fsmape_LR, final_score_LR_f],
    [rmse_LR_r, r_2_LR_r, mae_LR_r, smape_LR_r,fsmape_LR, final_score_LR_r]], 
    columns = ['RMSE', 'R_2', 'MAE', 'SMAPE','finalSMAPE', 'final_score'], 
    index = ['RF_F', 'RF_R', 'LR_R','LR_F']
)
df_final_metric
# Out:
#            RMSE       R_2        MAE      SMAPE  finalSMAPE  final_score
# RF_F   5.176124  0.661719   3.477704   5.732008    5.983736    -0.091733
# RF_R   6.286827  0.770781   3.195377   6.738919    5.983736    -0.437752
# LR_R  18.416400 -3.282312  16.563841  22.603230   19.117360    -0.261671
# LR_F  11.143458  0.279843   5.520545   8.659750   19.117360    -0.324118

# %%
random_state = RNS
cv = 5
models = [DecisionTreeRegressor(random_state = random_state), 
          RandomForestRegressor(random_state=random_state), 
          LinearRegression()]


results_cross_val = []

for model in models: 
    
    scorer = make_scorer(smape_scorer, greater_is_better=False) 
    
    cross_val_score_rougher = cross_val_score(model, 
                                              x_train, 
                                              y_train_r, 
                                              cv=cv, scoring=scorer).mean()
    cross_val_score_final = cross_val_score(model, 
                                            x_train,
                                            y_train_f, 
                                            cv=cv, scoring=scorer).mean()

    results_cross_val.append({'model name': model.__class__.__name__, 
                              'cross_val_score_rougher': cross_val_score_rougher, 
                              'cross_val_score_final': cross_val_score_final}) 
              
pd.DataFrame(results_cross_val)
# Out:
#               model name  cross_val_score_rougher  cross_val_score_final
# 0  DecisionTreeRegressor               -19.903402             -22.211743
# 1  RandomForestRegressor               -13.013572             -10.317634
# 2       LinearRegression               -10.774668             -10.578238

# %% [markdown]
# Лучшая модель по SMAPE RandomForestRegressor
#
# На тестовых выборках

# %%
predict_RF_r_test = rougher_model_LR.predict(x_test)
smape_rougher_t = smape_scorer(y_test_r, predict_RF_r_test)
print(smape_rougher_t)
# Out:
# 9.983587267100429

# %%
predict_RF_f_test = final_model_LR.predict(x_test)
smape_final_t = smape_scorer(y_test_f, predict_RF_f_test)
print(smape_final_t)
# Out:
# 23.197809025256774

# %%
dummy_regressor_rougher = DummyRegressor(strategy="median")
dummy_regressor_rougher.fit(x_train, y_train_r)
dummy_rougher_pred = dummy_regressor_rougher.predict(x_test)
smape_dummy_rougher = smape_scorer(y_test_r, dummy_rougher_pred)
print(smape_dummy_rougher)
# Out:
# 8.421012998208054

# %%
dummy_regressor_final = DummyRegressor(strategy="median")
dummy_regressor_final.fit(x_train, y_train_f)
dummy_final_pred = dummy_regressor_final.predict(x_test)
smape_dummy_final = smape_scorer(y_test_f, dummy_final_pred)
print(smape_dummy_final)
# Out:
# 9.181773574262182

# %%
final_smape_test = 0.25*smape_rougher_t + 0.75*smape_final_t
final_smape_dummy = 0.25*smape_dummy_rougher + 0.75*smape_dummy_final
print(final_smape_test , final_smape_dummy)
# Out:
# 19.89425358571769 8.991583430248651

# %%
***********

# %%
final_model_LR.fit(x_train, y_train_r)  # ВОТ ТУТ ОПИСКА - y_train_f скорее всего надо

# %% [raw]
# dummy_regressor_rougher = DummyRegressor(strategy="median")
# dummy_regressor_rougher.fit(X_train, y_train_rougher)
# dummy_rougher_pred = dummy_regressor_rougher.predict(X_test)
# smape_dummy_rougher = smape(y_test_rougher, dummy_rougher_pred)
# print(smape_dummy_rougher)
#
# И ДАЛЕЕ: ДЛЯ FINAL И ИТОГОВЫЙ

# %% [raw]
# # ПРОСТО ДЛЯ ОЗНАКОМЛЕНИЯ ВАРАИНТА КРОСС-ВАЛИДАЦИИ СО СВОЕЙ ФУНКЦИЕЙ
#
# random_state = 123
# cv = 5
# models = [DecisionTreeRegressor(random_state = random_state),
#           RandomForestRegressor(random_state=random_state),
#           LinearRegression()]
#
#
# results_cross_val = []
#
# for model in models:
#
#     scorer = make_scorer(smape, greater_is_better=False)
#
#     cross_val_score_rougher = cross_val_score(model,
#                                               features_train,
#                                               target_rougher_train,
#                                               cv=cv, scoring=scorer).mean()
#     cross_val_score_final = cross_val_score(model,
#                                             features_train,
#                                             target_final_train,
#                                             cv=cv, scoring=scorer).mean()
#
#     results_cross_val.append({'model name': model.__class__.__name__,
#                               'cross_val_score_rougher': cross_val_score_rougher,
#                               'cross_val_score_final': cross_val_score_final})
#
# pd.DataFrame(results_cross_val)

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке выполнения
# - [ ]  Выполнен шаг 1: данные подготовлены
#     - [ ]  Проверена формула вычисления эффективности обогащения
#     - [ ]  Проанализированы признаки, недоступные в тестовой выборке
#     - [ ]  Проведена предобработка данных
# - [ ]  Выполнен шаг 2: данные проанализированы
#     - [ ]  Исследовано изменение концентрации элементов на каждом этапе
#     - [ ]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [ ]  Исследованы суммарные концентрации
# - [ ]  Выполнен шаг 3: построена модель прогнозирования
#     - [ ]  Написана функция для вычисления итогового *sMAPE*
#     - [ ]  Обучено и проверено несколько моделей
#     - [ ]  Выбрана лучшая модель, её качество проверено на тестовой выборке
